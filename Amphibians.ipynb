# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
import pandas as pd
import numpy as np
import os
import pickle
import re
import nltk
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,AdaBoostClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, f1_score, fbeta_score, classification_report
from scipy.stats import hmean
from scipy.stats.mstats import gmean
import xgboost as xgb
from xgboost import XGBClassifier

# %%
col_names = ['ID', 'Motorway', 'SR', 'NR', 'TR', 'VR', 'SUR1', 'SUR2', 'SUR3','UR', 'FR', 'OR', 'RR', 'BR', 'MR', 'CR', 'Green frogs', 'Brown frogs','Common toad','Fire-bellied toad','Tree frog','Common newt','Great crested newt']
# load dataset
pima = pd.read_csv("dataset.csv")

# %%
pima.head()
# Out:
#    ID Motorway   SR  NR  TR  VR  SUR1  SUR2  SUR3  UR  ...  BR  MR  CR  \
# 0   1       A1  600   1   1   4     6     2    10   0  ...   0   0   1
# 1   2       A1  700   1   5   1    10     6    10   3  ...   1   0   1
# 2   3       A1  200   1   5   1    10     6    10   3  ...   1   0   1
# 3   4       A1  300   1   5   0     6    10     2   3  ...   0   0   1
# 4   5       A1  600   2   1   4    10     2     6   0  ...   5   0   1
#
#    Green frogs  Brown frogs  Common toad  Fire-bellied toad  Tree frog  \
# 0            0            0            0                  0          0
# 1            0            1            1                  0          0
# 2            0            1            1                  0          0
# 3            0            0            1                  0          0
# 4            0            1            1                  1          0
#
#    Common newt  Great crested newt
# 0            0                   0
# 1            1                   0
# ...

# %%
#split dataset in features and target variable
feature_cols = ['SR', 'NR', 'TR', 'VR', 'SUR1', 'SUR2', 'SUR3','UR', 'FR', 'OR', 'RR', 'BR', 'MR', 'CR']
target_cols = ['Green frogs', 'Brown frogs','Common toad','Fire-bellied toad','Tree frog','Common newt','Great crested newt']
X = pima[feature_cols] # Features
y = pima[target_cols] # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
def model_pipeline():
    pipeline = Pipeline([
        ('clf', MultiOutputClassifier(XGBClassifier(tree_method='hist',predictor='cpu_predictor',n_estimators=100, max_depth=5,
                                                    objective='multi:softmax',num_class=37,verbose=True)))
    ])

    return pipeline

# %%
model = []
model = model_pipeline()
model.fit(X_train, y_train)
# Out:
# [08:50:55] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [08:50:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [08:50:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
# ...

# %%
model.get_params()
# Out:
# {'memory': None,
#  'steps': [('clf',
#    MultiOutputClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                                  colsample_bylevel=None,
#                                                  colsample_bynode=None,
#                                                  colsample_bytree=None, gamma=None,
#                                                  gpu_id=None,
#                                                  importance_type='gain',
#                                                  interaction_constraints=None,
#                                                  learning_rate=None,
#                                                  max_delta_step=None, max_depth=5,
#                                                  min_child_weight=None,
#                                                  missing=nan,
#                                                  monotone_constraints=None,
# ...

# %%
param_grid = {
    'clf__estimator__colsample_bytree': [0.7, 0.8],
    'clf__estimator__max_depth': [5,7,9],
    'clf__estimator__reg_alpha': [1.1, 1.2, 1.3],
    'clf__estimator__reg_lambda': [1.1, 1.2, 1.3],
    'clf__estimator__subsample': [0.7, 0.8, 0.9],
}

# %%
CV_rfc = GridSearchCV(estimator=model, param_grid=param_grid, cv= 5)
CV_rfc.fit(X, y)
# Out:
# [08:51:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [08:51:01] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [08:51:01] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
# ...

# %%
# changes to grid cv
y_pred = CV_rfc.predict(X_test)

# %%
from sklearn.metrics import precision_recall_fscore_support
def get_results(y_test, y_pred):
    results = pd.DataFrame(columns=['Category', 'f_score', 'precision', 'recall'])
    num = 0
    for cat in y_test.columns:
        precision, recall, f_score, support = precision_recall_fscore_support(y_test[cat], y_pred[:,num], average='weighted')
        results.at[num+1, 'Category']= cat
        results.at[num+1, 'f_score']= f_score
        results.at[num+1, 'precision']= precision
        results.at[num+1, 'recall']= recall
        num += 1
    print('Aggregated f_score:', results['f_score'].mean())
    print('Aggregated precision:', results['precision'].mean())
    print('Aggregated recall:', results['recall'].mean())
    return results

# %%
get_results(y_test, y_pred)
# Out:
# Aggregated f_score: 0.9717419621833735
# Aggregated precision: 0.9734990950422432
# Aggregated recall: 0.9724310776942355
#              Category   f_score precision    recall
# 1         Green frogs  0.982456  0.983061  0.982456
# 2         Brown frogs  0.943538  0.950526  0.947368
# 3         Common toad   0.94765  0.948552  0.947368
# 4   Fire-bellied toad         1         1         1
# 5           Tree frog  0.982362   0.98293  0.982456
# 6         Common newt  0.964319  0.966624  0.964912
# 7  Great crested newt  0.981868    0.9828  0.982456

# %%
overall_accuracy = (y_pred == y_test).mean().mean()

print('Average overall accuracy {0:.2f}% \n'.format(overall_accuracy*100))
# Out:
# Average overall accuracy 97.24%

# %%
from sklearn.naive_bayes import GaussianNB

def model_pipeline_gaussiannb():
    pipeline = Pipeline([
        ('clf', MultiOutputClassifier(GaussianNB()))
    ])

    return pipeline

# %%
model = []
model = model_pipeline_gaussiannb()
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('clf', MultiOutputClassifier(estimator=GaussianNB()))])

# %%
y_pred = model.predict(X_test)

# %%
get_results(y_test, y_pred)
# Out:
# Aggregated f_score: 0.5953966837678026
# Aggregated precision: 0.6691957932033057
# Aggregated recall: 0.606516290726817
#              Category   f_score precision    recall
# 1         Green frogs  0.709427  0.748538  0.719298
# 2         Brown frogs  0.517195  0.694288   0.45614
# 3         Common toad  0.347407  0.495614  0.385965
# 4   Fire-bellied toad  0.657713  0.714554  0.701754
# 5           Tree frog  0.577263  0.579363  0.614035
# 6         Common newt  0.626316  0.640867  0.684211
# 7  Great crested newt  0.732456  0.811146  0.684211

# %%
from sklearn import tree

def model_pipeline_tree():
    pipeline = Pipeline([
        ('clf', MultiOutputClassifier(tree.DecisionTreeClassifier()))
    ])

    return pipeline

# %%
model = []
model = model_pipeline_tree()
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('clf',
#                  MultiOutputClassifier(estimator=DecisionTreeClassifier()))])

# %%
y_pred = model.predict(X_test)

# %%
get_results(y_test, y_pred)
# Out:
# Aggregated f_score: 0.6449233068041657
# Aggregated precision: 0.656215546666824
# Aggregated recall: 0.6466165413533834
#              Category   f_score precision    recall
# 1         Green frogs   0.62325  0.648222  0.631579
# 2         Brown frogs  0.749667  0.766102  0.736842
# 3         Common toad  0.573407  0.569201  0.578947
# 4   Fire-bellied toad  0.574017  0.569155  0.596491
# 5           Tree frog  0.586316  0.616282  0.578947
# 6         Common newt  0.599326  0.590138  0.614035
# 7  Great crested newt   0.80848  0.834408  0.789474

# %%
from sklearn.neighbors import KNeighborsClassifier

def model_pipeline_nn():
    pipeline = Pipeline([
        ('clf', MultiOutputClassifier(KNeighborsClassifier(n_neighbors=2)))
    ])

    return pipeline

# %%
model = []
model = model_pipeline_nn()
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('clf',
#                  MultiOutputClassifier(estimator=KNeighborsClassifier(n_neighbors=2)))])

# %%
y_pred = model.predict(X_test)
get_results(y_test, y_pred)
# Out:
# Aggregated f_score: 0.5735314079655245
# Aggregated precision: 0.5908487105695662
# Aggregated recall: 0.6115288220551377
#              Category   f_score precision    recall
# 1         Green frogs   0.69323   0.72253  0.701754
# 2         Brown frogs   0.58285  0.698026  0.526316
# 3         Common toad  0.350877  0.419393  0.350877
# 4   Fire-bellied toad  0.541502  0.589374  0.631579
# 5           Tree frog  0.496637  0.478786  0.561404
# 6         Common newt  0.538634  0.460287  0.649123
# 7  Great crested newt   0.81099  0.767544  0.859649

# %%
from sklearn import svm

def model_pipeline_svm():
    pipeline = Pipeline([
        ('clf', MultiOutputClassifier(svm.SVC()))
    ])

    return pipeline

model = []
model = model_pipeline_svm()
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('clf', MultiOutputClassifier(estimator=SVC()))])

# %%
y_pred = model.predict(X_test)
get_results(y_test, y_pred)
# Out:
# Aggregated f_score: 0.5894264989336582
# Aggregated precision: 0.5667101384709705
# Aggregated recall: 0.6942355889724311
# C:\Users\Siddharth\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#              Category   f_score precision    recall
# 1         Green frogs  0.323633  0.241305  0.491228
# 2         Brown frogs  0.745277  0.679902  0.824561
# 3         Common toad  0.511012   0.42136  0.649123
# 4   Fire-bellied toad  0.628835  0.797418  0.701754
# 5           Tree frog  0.541502  0.589374  0.631579
# 6         Common newt  0.555921  0.468144  0.684211
# 7  Great crested newt  0.819807  0.769468  0.877193

# %%
from sklearn.linear_model import RidgeClassifier

def model_pipeline_linear():
    pipeline = Pipeline([
        ('clf', MultiOutputClassifier(RidgeClassifier()))
    ])

    return pipeline

model = []
model = model_pipeline_svm()
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('clf', MultiOutputClassifier(estimator=SVC()))])

# %%
y_pred = model.predict(X_test)
get_results(y_test, y_pred)
# Out:
# Aggregated f_score: 0.5894264989336582
# Aggregated precision: 0.5667101384709705
# Aggregated recall: 0.6942355889724311
# C:\Users\Siddharth\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#              Category   f_score precision    recall
# 1         Green frogs  0.323633  0.241305  0.491228
# 2         Brown frogs  0.745277  0.679902  0.824561
# 3         Common toad  0.511012   0.42136  0.649123
# 4   Fire-bellied toad  0.628835  0.797418  0.701754
# 5           Tree frog  0.541502  0.589374  0.631579
# 6         Common newt  0.555921  0.468144  0.684211
# 7  Great crested newt  0.819807  0.769468  0.877193

# %%
def model_pipeline():
    pipeline = Pipeline([
        ('clf', MultiOutputClassifier(XGBClassifier(tree_method='hist',predictor='cpu_predictor',n_estimators=1000, max_depth=6,
                                                    objective='multi:softmax',num_class=37,verbose=True)))
    ])

    return pipeline

# %%
model = []
model = model_pipeline()
model.fit(X_train, y_train)
# Out:
# [18:06:29] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:06:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:06:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { verbose } might not be used.
#
# ...

# %%
model.get_params()
# Out:
# {'memory': None,
#  'steps': [('clf',
#    MultiOutputClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                                  colsample_bylevel=None,
#                                                  colsample_bynode=None,
#                                                  colsample_bytree=None, gamma=None,
#                                                  gpu_id=None,
#                                                  importance_type='gain',
#                                                  interaction_constraints=None,
#                                                  learning_rate=None,
#                                                  max_delta_step=None, max_depth=6,
#                                                  min_child_weight=None,
#                                                  missing=nan,
#                                                  monotone_constraints=None,
# ...

# %%
y_pred = model.predict(X_test)

# %%
get_results(y_test, y_pred)
# Out:
# Aggregated f_score: 0.6932130119845866
# Aggregated precision: 0.6954911585535772
# Aggregated recall: 0.706766917293233
#              Category   f_score precision    recall
# 1         Green frogs  0.683041  0.688684  0.684211
# 2         Brown frogs  0.706628  0.695041  0.719298
# 3         Common toad  0.649123  0.649123  0.649123
# 4   Fire-bellied toad  0.648101  0.651163  0.666667
# 5           Tree frog  0.686876   0.69121  0.684211
# 6         Common newt   0.69521   0.73188  0.736842
# 7  Great crested newt  0.783512  0.761337  0.807018
